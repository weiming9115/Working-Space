# %% [markdown]
# 2. Rainfall Characteristics
# This section highlights the different rainfall estimates from the 1-degree observational and reanalysis products. The key commands to launch the python script are below, and the command will output a 16-panel plot.

# %%
# %matplotlib inline
import warnings; warnings.filterwarnings('ignore')
#%run NASANEWS_teleport.py -ds yyyy-mm-dd -de yyyy-mm-dd -bbox S N W E -case name

#As an example:
# %run NASANEWS_teleport.py -ds 2009-08-07 -de 2009-08-09 -bbox 20 30 115 125 -case Morakot_Aug2009_accurain
# Out:
# No initial errors. Starting plot sequence...
# Plot sequence running... Please wait...
# Plot sequence complete. Rendering...
# SUCCESS! Your plot is complete...
# Plot saved as Morakot_Aug2009_accurain.png

# %% [markdown]
# 3. Basic Synoptic and Mesoscale Flows
# This section is where you can start to describe the broader scale synoptic and mesoscale flows associated with a case. Using these make_image and make_movie commands, images and animations can be extracted from the IDV. For animations, the loops will be based on the length of the time driver.

# %%
get_args()

# %%
bbox
# Out:
# [11, 21, 68, 78]

# %%
# %make_image -caption 'Place your caption here...' -capture legend
# Out:
# ERROR:root:Line magic function `%make_image` not found.

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %% [markdown]
# 4. Moisture Advection
# This section should focus on the moisture component of the case study, one of the three principal components to sustained convection. As before, use the make_image and make_movie commands to select your images and loops.

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend
# Out:
# ERROR:root:Line magic function `%make_image` not found.

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %% [markdown]
# 5. Vertical Structures
# This section should focus on the vertical cross sections of the case study that are carefully placed over the heavy rain event for clarity of explanation. This section should help to explain the dynamics and lift aspect of the case study (i.e. the other two ingredients along with lift).

# %%
# %make_image -caption 'Place your caption here...' -capture legend
# Out:
# ERROR:root:Line magic function `%make_image` not found.

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend
